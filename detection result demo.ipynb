# %%
import matplotlib
# %matplotlib inline
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys
sys.path.append('../training/')
sys.path.append('../')
from training.config_training import config 
sys.path.append('../preprocessing/')
from preprocessing.step1 import *
from preprocessing.full_prep import lumTrans
from layers import nms,iou

# %%
uid = '2503439e08a1e9232b80a625eeb26614'

img = np.load(f'prep_result/{uid}_clean.npy')
pbb = np.load(f'bbox_result/{uid}_pbb.npy')

# %%
pbb = pbb[pbb[:,0]>-1]

# %%
pbb = nms(pbb,0.05)
box = pbb[1].astype('int')[1:]

# %%
box
# Out:
# array([173,  37, 153,   9])

# %%
ax = plt.subplot(1,1,1)
plt.imshow(img[0,box[0]],'gray')
plt.axis('off')
rect = patches.Rectangle((box[2]-box[3],box[1]-box[3]),box[3]*2,box[3]*2,linewidth=2,edgecolor='red',facecolor='none')
ax.add_patch(rect)
